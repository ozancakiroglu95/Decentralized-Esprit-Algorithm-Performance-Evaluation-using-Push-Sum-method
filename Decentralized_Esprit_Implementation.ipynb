# %%
from doa_rmse_and_cramer_rao import rmse_and_cramer_rao
from armse import average_consensus_armse
import numpy as np
import pickle

# Number of sensors
M = 12

# Number of nodes
K = 6

# Number of sources
L = 3

# Locations of the nodes with respect to initial node
locations = (np.array([0,0]),np.array([0.45,0.99]),np.array([3.02,0.45]),np.array([5.61,0.90])
             ,np.array([8.03,1.46]),np.array([8.70,0.50]))

# Direction of arrivals
angles = np.array([5,-10,-14])*2*(np.pi)/360
K_l = np.array([np.sin(angles), np.cos(angles)])

for number in range(12):
    # Steering vector is implemented. It should have the shape: (12,3)
    for j in range(0,len(locations)):
        for i in range(0,len(angles)):
            first_part = np.exp(1j*np.pi*locations[j].dot(K_l[:,i]))
            second_part = np.array([1, np.exp(1j*np.pi*1*np.sin(angles[i]))])
            A_k = np.transpose(np.array(first_part*second_part, ndmin=2))
            if i == 0:
                B_k = A_k
            else:
                B_k = np.concatenate((B_k, A_k), axis=1)

            if i == len(angles)-1:
                if j == 0:
                    A = np.transpose(B_k)
                else:
                    A = np.concatenate((A, np.transpose(B_k)), axis=1)

    A = np.transpose(A)

    # Method_code = 1 is Average Consensus
    # Method_code = 2 is Push-Sum
    # Method_code = 3 is Conventional Esprit

    #method_code = 1
    #iteration = 20
    #SNR_range = (-20, 60)
    #N_samples_range = (100,101)
    #return_name = "rmse"
    #method = "ave"
    #rmse = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)
    #armse = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    #return_name = "cramer" 
    #rmse = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)
    #armse = average_consensus_armse(SNR_range, N_samples_range, iteration, A, angles, locations, K, L, M)
    
    if number == 0:
        iteration = 10
        SNR_range = (10, 11)
        N_samples_range = (2,1002)
        method = "push" 
        armse1 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    if number == 1:
        iteration = 20
        SNR_range = (10, 11)
        N_samples_range = (2,1002)
        method = "push" 
        armse2 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    if number == 2:
        iteration = 30
        SNR_range = (10, 11)
        N_samples_range = (2,1002)
        method = "push" 
        armse3 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    if number == 3:
        iteration = 10
        SNR_range = (10, 11)
        N_samples_range = (2,1002)
        method = "ave" 
        armse4 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    if number == 4:
        iteration = 20
        SNR_range = (10, 11)
        N_samples_range = (2,1002)
        method = "ave" 
        armse5 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    if number == 5:
        iteration = 30
        SNR_range = (10, 11)
        N_samples_range = (2,1002)
        method = "ave" 
        armse6 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

        
        
        
        
    if number == 6:
        iteration = 10
        SNR_range = (-20, 60)
        N_samples_range = (100,101)
        method = "push" 
        armse7 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)
        
    if number == 7:
        iteration = 20
        SNR_range = (-20, 60)
        N_samples_range = (100,101)
        method = "push" 
        armse8 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    if number == 8:
        iteration = 30
        SNR_range = (-20, 60)
        N_samples_range = (100,101)
        method = "push" 
        armse9 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    if number == 9:
        iteration = 10
        SNR_range = (-20, 60)
        N_samples_range = (100,101)
        method = "ave" 
        armse10 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    if number == 10:
        iteration = 20
        SNR_range = (-20, 60)
        N_samples_range = (100,101)
        method = "ave"
        armse11 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)

    if number == 11:
        iteration = 30
        SNR_range = (-20, 60)
        N_samples_range = (100,101)
        method = "ave"
        armse12 = average_consensus_armse(SNR_range, N_samples_range, iteration, method, A, angles, locations, K, L, M)


    

    
    
    
#     if number == 0:
#         iteration = 10
#         SNR_range = (10, 11)
#         N_samples_range = (2,1002)
#         method_code = 2
#         return_name = "rmse" 
#         rmse1 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 1:
#         iteration = 20
#         SNR_range = (10, 11)
#         N_samples_range = (2,1002)
#         method_code = 2
#         return_name = "rmse" 
#         rmse2 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 2:
#         iteration = 30
#         SNR_range = (10, 11)
#         N_samples_range = (2,1002)
#         method_code = 2
#         return_name = "rmse" 
#         rmse3 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 3:
#         iteration = 10
#         SNR_range = (10, 11)
#         N_samples_range = (2,1002)
#         method_code = 1
#         return_name = "rmse" 
#         rmse4 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 4:
#         iteration = 20
#         SNR_range = (10, 11)
#         N_samples_range = (2,1002)
#         method_code = 1
#         return_name = "rmse" 
#         rmse5 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 5:
#         iteration = 30
#         SNR_range = (10, 11)
#         N_samples_range = (2,1002)
#         method_code = 1
#         return_name = "rmse" 
#         rmse6 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 6:
#         iteration = 10
#         SNR_range = (10, 11)
#         N_samples_range = (2,1002)
#         method_code = 3
#         return_name = "rmse" 
#         rmse7 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)
        
        
        
        
        
#     if number == 7:
#         iteration = 10
#         SNR_range = (-20, 60)
#         N_samples_range = (100,101)
#         method_code = 2
#         return_name = "rmse" 
#         rmse8 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 8:
#         iteration = 20
#         SNR_range = (-20, 60)
#         N_samples_range = (100,101)
#         method_code = 2
#         return_name = "rmse" 
#         rmse9 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 9:
#         iteration = 30
#         SNR_range = (-20, 60)
#         N_samples_range = (100,101)
#         method_code = 2
#         return_name = "rmse" 
#         rmse10 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 10:
#         iteration = 10
#         SNR_range = (-20, 60)
#         N_samples_range = (100,101)
#         method_code = 1
#         return_name = "rmse" 
#         rmse11 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 11:
#         iteration = 20
#         SNR_range = (-20, 60)
#         N_samples_range = (100,101)
#         method_code = 1
#         return_name = "rmse" 
#         rmse12 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 12:
#         iteration = 30
#         SNR_range = (-20, 60)
#         N_samples_range = (100,101)
#         method_code = 1
#         return_name = "rmse" 
#         rmse13 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

#     if number == 13:
#         iteration = 10
#         SNR_range = (-20, 60)
#         N_samples_range = (100,101)
#         method_code = 3
#         return_name = "rmse" 
#         rmse14 = rmse_and_cramer_rao(SNR_range, N_samples_range, iteration, A, angles, locations, K, method_code, return_name)

        
# with open("data/snr_1000_samples_data/Push_Sum_ESPRIT_1000_sample_P_10.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse1, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_1000_samples_data/Push_Sum_ESPRIT_1000_sample_P_20.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse2, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_1000_samples_data/Push_Sum_ESPRIT_1000_sample_P_30.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse3, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_1000_samples_data/Average_Consensus_ESPRIT_1000_sample_P_10.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse4, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_1000_samples_data/Average_Consensus_ESPRIT_1000_sample_P_20.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse5, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_1000_samples_data/Average_Consensus_ESPRIT_1000_sample_P_30.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse6, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_1000_samples_data/Conventional_ESPRIT_1000_sample.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse7, fp, protocol=pickle.HIGHEST_PROTOCOL)


# with open("data/snr_10_dB_data/Push_Sum_ESPRIT_SNR_10db_P_10.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse8, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_10_dB_data/Push_Sum_ESPRIT_SNR_10db_P_20.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse9, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_10_dB_data/Push_Sum_ESPRIT_SNR_10db_P_30.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse10, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_10_dB_data/Average_Consensus_ESPRIT_SNR_10db_P_10.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse11, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_10_dB_data/Average_Consensus_ESPRIT_SNR_10db_P_20.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse12, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_10_dB_data/Average_Consensus_ESPRIT_SNR_10db_P_30.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse13, fp, protocol=pickle.HIGHEST_PROTOCOL)

# with open("data/snr_10_dB_data/Conventional_ESPRIT_SNR_10db.txt", "wb") as fp:   # Unpickling
#     pickle.dump(rmse14, fp, protocol=pickle.HIGHEST_PROTOCOL)

    
    
    
    
    
    
with open("data/armse_snr_1000_samples_data/armse_Push_Sum_ESPRIT_1000_sample_P_10.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse1, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Push_Sum_ESPRIT_1000_sample_P_20.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse2, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Push_Sum_ESPRIT_1000_sample_P_30.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse3, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Average_Consensus_ESPRIT_1000_sample_P_10.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse4, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Average_Consensus_ESPRIT_1000_sample_P_20.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse5, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Average_Consensus_ESPRIT_1000_sample_P_30.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse6, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Push_Sum_ESPRIT_SNR_10db_P_10.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse7, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Push_Sum_ESPRIT_SNR_10db_P_20.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse8, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Push_Sum_ESPRIT_SNR_10db_P_30.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse9, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Average_Consensus_ESPRIT_SNR_10db_P_10.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse10, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Average_Consensus_ESPRIT_SNR_10db_P_20.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse11, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Average_Consensus_ESPRIT_SNR_10db_P_30.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse12, fp, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 17.031556831216164
# 10.857526084085896
# 11.77197857455218
# 11.276962330209022
# 6.779520572900435
# 7.215872018751397
# 6.154878187009721
# 17.438802640885843
# 6.1663951380676965
# 5.085479002516277
# 5.735580046806519
# 3.6230809236194808
# 3.5281139582140937
# 4.474895913921395
# 4.406934107243831
# 5.311960845284412
# 3.314893418275641
# 5.9710849778479975
# 3.0674905190608937
# 3.770681942116425
# 3.097408323369795
# 4.520497635943509
# 2.321254700628644
# 2.8497326785177
# 3.6297673670078914
# 2.0951302807681267
# 2.8239312324016037
# 2.9196384187468327
# 2.4743783602615173
# 2.636122289397049
# 3.0004242061476987
# 3.1304788762598905
# 3.0235648434041047
# 1.830621535151787
# 2.5277222518203226
# 3.014083103716363
# 1.8302516281028542
# 2.2174648934026497
# 2.361249271945355
# 2.150838757789329
# 1.9619198833373643
# 1.8136386871130399
# 1.895543348534736
# 2.3034578541927657
# 2.030600329378524
# 2.204498475948819
# 1.8651266637473314
# 2.2875652016526904
# ...

# %%
with open("data/armse_snr_1000_samples_data/armse_Push_Sum_ESPRIT_1000_sample_P_10.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse1, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Push_Sum_ESPRIT_1000_sample_P_20.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse2, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Push_Sum_ESPRIT_1000_sample_P_30.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse3, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Average_Consensus_ESPRIT_1000_sample_P_10.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse4, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Average_Consensus_ESPRIT_1000_sample_P_20.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse5, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_1000_samples_data/armse_Average_Consensus_ESPRIT_1000_sample_P_30.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse6, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Push_Sum_ESPRIT_SNR_10db_P_10.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse7, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Push_Sum_ESPRIT_SNR_10db_P_20.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse8, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Push_Sum_ESPRIT_SNR_10db_P_30.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse9, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Average_Consensus_ESPRIT_SNR_10db_P_10.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse10, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Average_Consensus_ESPRIT_SNR_10db_P_20.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse11, fp, protocol=pickle.HIGHEST_PROTOCOL)

with open("data/armse_snr_10_dB_data/armse_Average_Consensus_ESPRIT_SNR_10db_P_30.txt", "wb") as fp:   # Unpickling
    pickle.dump(armse12, fp, protocol=pickle.HIGHEST_PROTOCOL)
