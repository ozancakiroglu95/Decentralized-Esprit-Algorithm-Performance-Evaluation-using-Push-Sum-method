# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

with open("data/snr_1000_samples_data/Push_Sum_ESPRIT_1000_sample_P_10.txt", "rb") as fp:   # Unpickling
    push_sum_1000_sample_p_10 = pickle.load(fp)
    
with open("data/snr_1000_samples_data/Push_Sum_ESPRIT_1000_sample_P_20.txt", "rb") as fp:   # Unpickling
    push_sum_1000_sample_p_20 = pickle.load(fp)
    
with open("data/snr_1000_samples_data/Push_Sum_ESPRIT_1000_sample_P_30.txt", "rb") as fp:   # Unpickling
    push_sum_1000_sample_p_30 = pickle.load(fp)

with open("data/snr_1000_samples_data/Average_Consensus_ESPRIT_1000_sample_P_10.txt", "rb") as fp:   # Unpickling
    ave_cons_1000_sample_p_10 = pickle.load(fp)
    
with open("data/snr_1000_samples_data/Average_Consensus_ESPRIT_1000_sample_P_20.txt", "rb") as fp:   # Unpickling
    ave_cons_1000_sample_p_20 = pickle.load(fp)

with open("data/snr_1000_samples_data/Average_Consensus_ESPRIT_1000_sample_P_30.txt", "rb") as fp:   # Unpickling
    ave_cons_1000_sample_p_30 = pickle.load(fp)

with open("data/snr_1000_samples_data/Conventional_ESPRIT_1000_sample.txt", "rb") as fp:   # Unpickling
    conv_1000_sample_p_30 = pickle.load(fp)

plt.plot(np.arange(2,1002), push_sum_1000_sample_p_10, 'r-', label='Push-Sum Iteration:10')
plt.plot(np.arange(2,1002), push_sum_1000_sample_p_20, 'r--', label='Push-Sum Iteration:20')
plt.plot(np.arange(2,1002), push_sum_1000_sample_p_30, 'r-.', label='Push-Sum Iteration:30')
plt.plot(np.arange(2,1002), ave_cons_1000_sample_p_10, 'b-', label='Average Consensus Iteration:10')
plt.plot(np.arange(2,1002), ave_cons_1000_sample_p_20, 'b--', label='Average Consensus Iteration:20')
plt.plot(np.arange(2,1002), ave_cons_1000_sample_p_30, 'b-.', label='Average Consensus Iteration:30')
plt.plot(np.arange(2,1002), conv_1000_sample_p_30, 'g--', label='Conventional ESPRIT')
plt.legend()
plt.yscale("log")
plt.xlabel('Number of Samples N')
plt.ylabel('RMSE (degree)')
plt.show()

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import bottleneck as bn
from matplotlib.pyplot import figure

figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

with open("data/snr_10_dB_data/Push_Sum_ESPRIT_SNR_10db_P_10.txt", "rb") as fp:   # Unpickling
    push_sum_1000_sample_p_10 = pickle.load(fp)
    
with open("data/snr_10_dB_data/Push_Sum_ESPRIT_SNR_10db_P_20.txt", "rb") as fp:   # Unpickling
    push_sum_1000_sample_p_20 = pickle.load(fp)
    
with open("data/snr_10_dB_data/Push_Sum_ESPRIT_SNR_10db_P_30.txt", "rb") as fp:   # Unpickling
    push_sum_1000_sample_p_30 = pickle.load(fp)

with open("data/snr_10_dB_data/Average_Consensus_ESPRIT_SNR_10db_P_10.txt", "rb") as fp:   # Unpickling
    ave_cons_1000_sample_p_10 = pickle.load(fp)
    
with open("data/snr_10_dB_data/Average_Consensus_ESPRIT_SNR_10db_P_20.txt", "rb") as fp:   # Unpickling
    ave_cons_1000_sample_p_20 = pickle.load(fp)

with open("data/snr_10_dB_data/Average_Consensus_ESPRIT_SNR_10db_P_30.txt", "rb") as fp:   # Unpickling
    ave_cons_1000_sample_p_30 = pickle.load(fp)

with open("data/snr_10_dB_data/Conventional_ESPRIT_SNR_10db.txt", "rb") as fp:   # Unpickling
    conv_1000_sample_p_30 = pickle.load(fp)

with open("data/cramer_rao_data/Cramer_Rao_Bound_SNR_10db.txt", "rb") as fp:   # Unpickling
    cramer_rao = pickle.load(fp)
    
with open("data/armse_SNR_iteration.txt", "rb") as fp:   # Unpickling
    armse = pickle.load(fp)
    
with open("data/armse_ave2.txt", "rb") as fp:   # Unpickling
    armse2 = pickle.load(fp)
    
with open("data/armse_ave_20_SNR.txt", "rb") as fp:   # Unpickling
    armse3 = pickle.load(fp)

plt.plot(np.arange(-20,60), push_sum_1000_sample_p_10, 'r-', label='Push-Sum Iteration:10')
plt.plot(np.arange(-20,60), push_sum_1000_sample_p_20, 'r--', label='Push-Sum Iteration:20')
plt.plot(np.arange(-20,60), push_sum_1000_sample_p_30, 'r-.', label='Push-Sum Iteration:30')
plt.plot(np.arange(-20,60), ave_cons_1000_sample_p_10, 'b-', label='Average Consensus Iteration:10')
plt.plot(np.arange(-20,60), ave_cons_1000_sample_p_20, 'b--', label='Average Consensus Iteration:20')
plt.plot(np.arange(-20,60), ave_cons_1000_sample_p_30, 'b-.', label='Average Consensus Iteration:30')
plt.plot(np.arange(-20,60), conv_1000_sample_p_30, 'g--', label='Conventional ESPRIT')


#plt.plot(np.arange(-20,60), cramer_rao, 'c--', label='Cramer Rao Bound')
plt.legend()
plt.yscale("log")
plt.xlabel('SNR (dB)')
plt.ylabel('RMSE (degree)')
plt.show()

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

with open("data/armse_snr_1000_samples_data/armse_Push_Sum_ESPRIT_1000_sample_P_10.txt", "rb") as fp:   # Unpickling
    armse_push_sum_1000_sample_p_10 = pickle.load(fp)
    
with open("data/armse_snr_1000_samples_data/armse_Push_Sum_ESPRIT_1000_sample_P_20.txt", "rb") as fp:   # Unpickling
    armse_push_sum_1000_sample_p_20 = pickle.load(fp)
    
with open("data/armse_snr_1000_samples_data/armse_Push_Sum_ESPRIT_1000_sample_P_30.txt", "rb") as fp:   # Unpickling
    armse_push_sum_1000_sample_p_30 = pickle.load(fp)

with open("data/armse_snr_1000_samples_data/armse_Average_Consensus_ESPRIT_1000_sample_P_10.txt", "rb") as fp:   # Unpickling
    armse_ave_cons_1000_sample_p_10 = pickle.load(fp)
    
with open("data/armse_snr_1000_samples_data/armse_Average_Consensus_ESPRIT_1000_sample_P_20.txt", "rb") as fp:   # Unpickling
    armse_ave_cons_1000_sample_p_20 = pickle.load(fp)

with open("data/armse_snr_1000_samples_data/armse_Average_Consensus_ESPRIT_1000_sample_P_30.txt", "rb") as fp:   # Unpickling
    armse_ave_cons_1000_sample_p_30 = pickle.load(fp)

plt.plot(np.arange(2,1002), armse_push_sum_1000_sample_p_10, 'r-',  label='ARMSE Push-Sum Iteration:10')
plt.plot(np.arange(2,1002), armse_push_sum_1000_sample_p_20, 'r--', label='ARMSE Push-Sum Iteration:20')
plt.plot(np.arange(2,1002), armse_push_sum_1000_sample_p_30, 'r-.', label='ARMSE Push-Sum Iteration:30')
plt.plot(np.arange(2,1002), armse_ave_cons_1000_sample_p_10, 'b-',  label='ARMSE Average Consensus Iteration:10')
plt.plot(np.arange(2,1002), armse_ave_cons_1000_sample_p_20, 'b--', label='ARMSE Average Consensus Iteration:20')
plt.plot(np.arange(2,1002), armse_ave_cons_1000_sample_p_30, 'b-.', label='ARMSE Average Consensus Iteration:30')
plt.legend()
plt.yscale("log")
plt.xlabel('Number of Samples N')
plt.ylabel('RMSE (degree)')
plt.show()

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import bottleneck as bn
from matplotlib.pyplot import figure

figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

with open("data/armse_snr_10_dB_data/armse_Push_Sum_ESPRIT_SNR_10db_P_10.txt", "rb") as fp:   # Unpickling
    armse_push_sum_1000_sample_p_10 = pickle.load(fp)
    
with open("data/armse_snr_10_dB_data/armse_Push_Sum_ESPRIT_SNR_10db_P_20.txt", "rb") as fp:   # Unpickling
    armse_push_sum_1000_sample_p_20 = pickle.load(fp)
    
with open("data/armse_snr_10_dB_data/armse_Push_Sum_ESPRIT_SNR_10db_P_30.txt", "rb") as fp:   # Unpickling
    armse_push_sum_1000_sample_p_30 = pickle.load(fp)

with open("data/armse_snr_10_dB_data/armse_Average_Consensus_ESPRIT_SNR_10db_P_10.txt", "rb") as fp:   # Unpickling
    armse_ave_cons_1000_sample_p_10 = pickle.load(fp)
    
with open("data/armse_snr_10_dB_data/armse_Average_Consensus_ESPRIT_SNR_10db_P_20.txt", "rb") as fp:   # Unpickling
    armse_ave_cons_1000_sample_p_20 = pickle.load(fp)

with open("data/armse_snr_10_dB_data/armse_Average_Consensus_ESPRIT_SNR_10db_P_30.txt", "rb") as fp:   # Unpickling
    armse_ave_cons_1000_sample_p_30 = pickle.load(fp)

plt.plot(np.arange(-20,60), armse_push_sum_1000_sample_p_10, 'r-',  label='ARMSE Push-Sum Iteration:10')
plt.plot(np.arange(-20,60), armse_push_sum_1000_sample_p_20, 'r--', label='ARMSE Push-Sum Iteration:20')
plt.plot(np.arange(-20,60), armse_push_sum_1000_sample_p_30, 'r-.', label='ARMSE Push-Sum Iteration:30')
plt.plot(np.arange(-20,60), armse_ave_cons_1000_sample_p_10, 'b-',  label='ARMSE Average Consensus Iteration:10')
plt.plot(np.arange(-20,60), armse_ave_cons_1000_sample_p_20, 'b--', label='ARMSE Average Consensus Iteration:20')
plt.plot(np.arange(-20,60), armse_ave_cons_1000_sample_p_30, 'b-.', label='ARMSE Average Consensus Iteration:30')

plt.legend()
plt.yscale("log")
plt.xlabel('SNR (dB)')
plt.ylabel('RMSE (degree)')
plt.show()
